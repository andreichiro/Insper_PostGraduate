# %% [markdown]
# ![Insper](https://github.com/danielscarvalho/Insper-DS-Dicas/blob/master/Insper-Logo.png?raw=true)
#
# # Insper Pós-Graduação
# ## Programa Avançado em Data Science e Decisão [»](https://www.insper.edu.br/pt/cursos/pos-graduacao/programas-avancados/programas-avancados-data-science-e-decisao)

# %% [markdown]
# # Aula 04 - Gráficos em Python (Matplotlib)

# %% [markdown]
# Matplotlib é uma das mais populares bibliotecas para construção de gráficos em Python. E também a base para outras bibliotecas mais recentes.
#
# Em suas origens, matplotlib buscava seguir um approach MATLAB para construção de gráficos. Posteriormente, buscou-se adotar um paradigma orientado a objetos para a sua construção.
#
# Este é um dos motivos que você vai encontrar alguns códigos que seguem o estilo MATLAB (estruturado) e outros que seguem a orientação a objetos. É aconselhável que você conheça ambas as formas, mas que pratique a última.

# %% [markdown]
# Para compreender o matplotlib é importante entender a anatomia de um gráfico em Python.
#
# ![image.png](attachment:33f1eae5-cdfd-4b75-8a08-d136ad40a9fe.png)
# <!--
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/figure_axes_axis_labeled.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/figure_axes_axis_labeled.png)
# -->
#
# Ref: https://matplotlib.org/stable/users/explain/quick_start.html

# %% [markdown]
# ![https://geo-python.github.io/site/2017/_images/basic-elements-of-plot.png](https://geo-python.github.io/site/2017/_images/basic-elements-of-plot.png)

# %% [markdown]
# ## O estilo MATLAB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
x = np.linspace(0, 10, 100)

# criamos a figure
plt.figure()

# criamos o primeiro subplot 
plt.subplot(2, 1, 1) # (rows, columns, painel number)

# realizamos o plot no primeiro subplot
plt.plot(x, np.sin(x))

# criamos o segundo subplot
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# Essa abordagem é muito utilizada, principalmente pelos usuários que migraram de outras plataformas para o Python.
#
# Observe que ela é *stateful*, isto é, ela mantém o controle de qual é o subplot atual, sob o qual os comandos `plt.plot` são aplicados.

# %% [markdown]
# ## O estilo orientado a objetos
#
# Outra forma (mais recomendada) é a orientada a objetos. Nela nós instanciamos um objeto `figure` e outro `axes` e por meio dessas referências controlamos melhor uma imagem gerada no matplotlib.
#
# Vamos reproduzir o mesmo gráfico do slide anterior, porém sob este paradigma.

# %%
a, b = [100, 200] #Pythonico!

# %%
a

# %%
b

# %%
x

# %%
np.sin(x)

# %%
fig, ax = plt.subplots(2) # indicamos que queremos 2 subplots

ax[0].plot(x, np.sin(x)) #Zero é sempre o primeiro!
ax[1].plot(x, np.cos(x))

# %%
ax

# %%
ax[0]

# %%
ax[1]

# %%
type(ax[0])

# %%
type(ax)

# %%
type(fig)

# %% [markdown]
# Você consegue notar as vantagens/desvantagens desse modo de produzir um gráfico?

# %% [markdown]
# Vamos fazer um gráfico com dados sintéticos e ver as possibilidades de customização.

# %%
people = ['Ann','Brandon','Chen','David','Emily','Farook',
          'Gagan','Hamish','Imran','Julio','Katherine','Lily']

age = [21,12,32,45,37,18,28,52,5,40,48,15]
weight = [55,35,77,68,70,60,72,69,18,65,82,48]
height = [160,135,170,165,173,168,175,159,105,171,155,158]

# %%
fig, ax = plt.subplots()
ax.scatter(age, height)
plt.show()

# %% [markdown]
# ### Ajustes finos
#
# Fizemos um gráfico básico, mas queremos mais! Vamos ver como podemos melhorar. Vamos definir:
#
# - O tamanho da figura
# - O título da figura (e o tamanho da fonte)
# - Os rótulos dos eixos X e Y
# - Os ticks dos eixos X e Y
# - Ativar Grid
# - Fazer alguma anotação no gráfico
# - Inserir uma legenda
# - Adicionar linhas horizontais/verticiais
#
# Passo a passo:

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10,10))

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))

# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic');

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))

# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')

# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))

# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')

# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);

# ativar Grid
ax.grid(True);

# %%
[i*5 for i in range(12)]

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))

# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')

# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);

# ativar Grid
ax.grid(True)

# X e Y ticks
ax.set_xticks([i*5 for i in range(12)])
ax.tick_params(axis="x", labelsize=12)

ax.set_ylim(100,200)
ax.tick_params(axis="y", labelsize=12);

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))

# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')

# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);

# ativar Grid
ax.grid(True)

# X e Y ticks
ax.set_xticks([i*5 for i in range(12)])
ax.tick_params(axis="x", labelsize=12)
ax.set_ylim(100,200)
ax.tick_params(axis="y", labelsize=12);

# vamos plotar os dados
ax.scatter(x = age, y = height, c = 'orange', s = 150, edgecolors = 'g');

# %% [markdown]
# Você compreende que a cor preta é indicada por `k`?
#
# Outras cores:
#
# b: blue
#
# g: green
#
# r: red
#
# c: cyan
#
# m: magenta
#
# y: yellow
#
# k: black
#
# w: white
#
# > Consulte a documentação online da biblioteca para mais detalhes e opções

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))
# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')
# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);
# ativar Grid
ax.grid(True)
# X e Y ticks
ax.set_xticks([i*5 for i in range(12)])
ax.tick_params(axis="x", labelsize=12)
ax.set_ylim(100,200)
ax.tick_params(axis="y", labelsize=12);
# vamos plotar os dados
ax.scatter(x = age, y = height, c = 'orange', s = 150, edgecolors = 'k')

# adicionar anotações na imagem
ax.text(x = 15, y = 105, s = 'Há crescimento até 20 anos,\n depois há uma certa estabilidade',
       fontsize=12, rotation=90, linespacing=2)

ax.text(x = 22, y = 185, s = 'Ninguém possui mais que 180 cm', fontsize=12);

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))

# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')

# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);

# ativar Grid
ax.grid(True)

# X e Y ticks
ax.set_xticks([i*5 for i in range(12)])
ax.tick_params(axis="x", labelsize=12)
ax.set_ylim(100,200)
ax.tick_params(axis="y", labelsize=12);

# vamos plotar os dados
ax.scatter(x = age, y = height, c = 'orange', s = 150, edgecolors = 'k')

# adicionar anotações na imagem
ax.text(x = 15, y = 105, s = 'Há crescimento até 20 anos,\n depois há uma certa estabilidade',
       fontsize=12, rotation=30, linespacing=2)

ax.text(x = 22, y = 185, s = 'Ninguém possui mais que 180 cm', fontsize=12);

# adicionar linhas
ax.vlines(x = 20, ymin = 100, ymax=180, linestyles='dashed', color='blue', lw=3)
ax.hlines(y = 180, xmin=0, xmax= 55, linestyles='dashed', color='red', lw=3);

# %%
# tamanho da figura
fig, ax = plt.subplots(figsize=(10, 8))
# título do gráfico
ax.set_title('Gráfico da Idade vs. Altura (em cm)',
             fontsize=20, fontstyle='italic')
# rótulos dos eixos X e Y
ax.set_xlabel('Idade (anos)', fontsize=16)
ax.set_ylabel('Altura (cm)', fontsize=16);
# ativar Grid
ax.grid(True)
# X e Y ticks
ax.set_xticks([i*5 for i in range(12)])
ax.tick_params(axis="x", labelsize=12)
ax.set_ylim(100,200)
ax.tick_params(axis="y", labelsize=12);
# vamos plotar os dados
ax.scatter(x = age, y = height, c = 'orange', s = 150, edgecolors = 'k')

# adicionar anotações na imagem
ax.text(x = 15, y = 105, s = 'Há crescimento até 20 anos,\n depois há uma certa estabilidade',
       fontsize=12, rotation=30, linespacing=2)
ax.text(x = 22, y = 185, s = 'Ninguém possui mais que 180 cm', fontsize=12);

# adicionar linhas
ax.vlines(x = 20, ymin = 100, ymax=180, linestyles='dashed', color='blue', lw=3)
ax.hlines(y = 180, xmin=0, xmax= 55, linestyles='dashed', color='red', lw=3);

# legendas
ax.legend(['Altura em cm'], loc='lower right', fontsize=14)
plt.show()

# %% [markdown]
# Outro gráfico, agora para observar o peso das pessoas.

# %%
fig, ax = plt.subplots(figsize=(12, 4))

ax.set_title('Peso dos indivíduos (em Kg)', fontsize=16, fontstyle='italic')

ax.bar(x=people, height=weight, width=0.6,
       color='orange', edgecolor='b', alpha=0.6)

ax.set_xlabel('Indivíduos', fontsize=15)
ax.set_ylabel('Peso (em Kg)', fontsize=15)

ax.tick_params(axis="x", labelsize=12, rotation=30)
ax.tick_params(axis="y", labelsize=12)

plt.show()

# %% [markdown]
# ## Exercício
#
# Agora é a sua vez de praticar. Tente reproduzir o seguinte gráfico:
#
# ![image.png](attachment:a42d732c-b663-4a40-bbfa-9366bfde5766.png)!
#
# <!--
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/exercise_1-1.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/exercise_1-1.png)
#
# -->

# %% [markdown]
# Abaixo há um código básico, para que você complemente. Lembre-se de usar o `plt.subplots()` para construir os múltiplos subplots.
#
# ![image.png](attachment:4d89f8b8-08bc-49de-bc03-e68b292d0047.png)
# <!--
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/exercise_1-1.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/exercise_1-1.png)
# -->

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y1, y2, y3 = np.cos(x), np.cos(x+1), np.cos(x+3)
names = ['Signal 1', 'Signal 2', 'Signal 3']

# %% [markdown]
# Agora você desenvolve o restante da solução ...

# %% [markdown]
# Resolução

# %%
zip([1,2,3],["a","b","c"])
list(_)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1, 10, 100)
y1, y2, y3 = np.cos(x), np.sin(x+1), np.tan(x+3)
names = ['Signal 1 - cos', 'Signal 2 - sin', 'Signal 3 - tan']

fig, axes = plt.subplots(nrows=3, figsize=(10, 8))

for ax, y, name in zip(axes, (y1, y2, y3), names):
    ax.plot(x, y, color='blue')
    ax.set_title(name, fontsize=14)
    ax.set(xticks=[], yticks=[])
    ax.set_xlim((0,10))

plt.show()

# %% [markdown]
# Outros possíveis gráficos:
#
# ![image.png](attachment:69525e47-b684-443e-aa3c-d3c5c7f80aa1.png)
#
# Ref: https://medium.com/towards-data-science/python-data-visualization-with-matplotlib-part-2-66f1307d42fb
#
# ![image.png](attachment:db836f6d-0d52-47ef-ab8d-ba285f9025c8.png)
#
# Ref: https://medium.com/@si.radiumsodium/anatomy-of-matplotlib-object-oriented-method-183e9eecd9c5

# %% [markdown]
# <!--
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/plot_example.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/plot_example.png)
#
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/scatter_example.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/scatter_example.png)
#
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/bar_example.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/bar_example.png)
#
# ![https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/statistical_example.png](https://nbviewer.jupyter.org/github/matplotlib/AnatomyOfMatplotlib/blob/master/images/statistical_example.png)
# -->

# %% [markdown]
# Marcadores
#
# Há uma gama de marcadores para os gráficos. Veja alguns.

# %%
xs, ys = np.mgrid[:4, 9:0:-1]
markers = [".", "+", ",", "x", "o", "D", "d", "", "8", "s", "p", "*", "|", "_", "h", "H", 0, 4, "<", "3",
           1, 5, ">", "4", 2, 6, "^", "2", 3, 7, "v", "1", "None", None, " ", ""]

descripts = ["point", "plus", "pixel", "cross", "circle", "diamond", "thin diamond", "",
             "octagon", "square", "pentagon", "star", "vertical bar", "horizontal bar", "hexagon 1", "hexagon 2",
             "tick left", "caret left", "triangle left", "tri left", "tick right", "caret right", "triangle right", "tri right",
             "tick up", "caret up", "triangle up", "tri up", "tick down", "caret down", "triangle down", "tri down",
             "Nothing", "default", "Nothing", "Nothing"]

fig, ax = plt.subplots(1, 1, figsize=(7.5, 4))
for x, y, m, d in zip(xs.T.flat, ys.T.flat, markers, descripts):
    ax.scatter(x, y, marker=m, s=100)
    ax.text(x + 0.1, y - 0.1, d, size=14)
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Random Walk (fill between)
#
# Random Walk - [Passeio Aleatório](https://pt.wikipedia.org/wiki/Passeio_aleat%C3%B3rio) - [MathWorld](https://mathworld.wolfram.com/RandomWalk1-Dimensional.html)

# %%
np.random.randn(20).cumsum()

# %%
np.linspace(0, 10, 20)

# %%
np.random.seed(1) #Pseudo Aleatórios

y = np.random.randn(100).cumsum()
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots(figsize=(10,8))

ax.plot(x, y)
plt.show()

# %%
np.random.seed(1)

y = np.random.randn(100).cumsum()
x = np.linspace(0, 10, 100)

fig, ax = plt.subplots(figsize=(10,8))

ax.fill_between(x, y, alpha=0.4, edgecolor='k')
plt.show()

# %% [markdown]
# ## Exibindo barras de erro

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# Listar estilos (style) disponíveis

# %%
plt.style.available

# %%
plt.figure(figsize=(10, 10))
x = np.linspace(0, 10, 50)

dy = 0.8

y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')

# %% [markdown]
# - Erros contínuos

# %%
from sklearn.gaussian_process import GaussianProcessRegressor

# %%
def model(x): return x * np.sin(x)


xdata = np.array([1, 3, 5, 6, 8, 10])
ydata = model(xdata)

# %%
xdata

# %%
ydata

# %%
gp = GaussianProcessRegressor()

# %%
xdata.reshape(-1, 1)

# %%
gp.fit(xdata.reshape(-1, 1), ydata)

# %%
xfit = np.linspace(0, 10, 1000)
yfit, std = gp.predict(xfit.reshape(-1, 1), return_std=True)

# %%
xfit

# %%
yfit

# %%
dyfit = 2 * std # 95% confidence interval

# %%
plt.figure(figsize=(15, 10))

plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')

plt.fill_between(xfit, yfit - dyfit, yfit + dyfit, color='gray',
   alpha=0.2,  label='95% confidence interval')

plt.legend(loc='upper left',  labelcolor='k')
plt.show()

# %% [markdown]
# ## Múltiplos Subplots

# %% [markdown]
# Ainda usando o Matplotlib...

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10,8))

plt.subplots_adjust(hspace=0.3, wspace=0.2)

for i in range(2):
    for j in range(3):
        axes[i,j].text(0.5, 0.5, str((i,j)), fontsize=18, ha='center')
        axes[i,j].grid(False)

# %% [markdown]
# ## Matplotlib em 3D

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))

ax = Axes3D(fig)

X = np.arange(-2, 2, 0.1)
Y = np.arange(-2, 2, 0.1)
X, Y = np.meshgrid(X, Y)

def f(x, y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)

ax.plot_surface(X, Y, f(X, Y), rstride=1, cstride=1)

# %% [markdown]
# Meshgrid - superfície 3D
#
# 3 eixos X, Y e Z (que é a profundidade)
#
# ![https://static.packt-cdn.com/products/9781786463517/graphics/meshgrid.jpg](https://static.packt-cdn.com/products/9781786463517/graphics/meshgrid.jpg)

# %% [markdown]
# # Gráficos com Seaborn

# %% [markdown]
# Inicialmente vamos comparar o Matplotlib com o Seaborn:
#
# 1. Gráfico clássico com Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('classic')
import numpy as np
import pandas as pd

# %%
rng = np.random.RandomState(0)

x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
type(rng)

# %%
x

# %%
y

# %%
plt.plot(x,y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

plt.show()

# %% [markdown]
# 2. Gráfico com Seaborn

# %%
import seaborn as sns
sns.set()

# %%
plt.plot(x,y)
plt.legend('ABCDEF', ncol=2, loc='upper left')
plt.show()

# %% [markdown]
# ## O quarteto de Anscombe
#
# O Quarteto de Anscombe são quatro conjuntos de dados que têm estatísticas descritivas quase idênticas (como a média e a variância), mas que têm distribuições muito diferentes e aparências muito distintas quando exibidos graficamente. [Wikipedia](https://pt.wikipedia.org/wiki/Quarteto_de_Anscombe)
#
# É um clássico em ciências dos dados...
#
# O Seaborn tem diversos conuntos de dados (datasets) classicos disponíveis:

# %%
sns.get_dataset_names()

# %%
sns.set(style='ticks')
df = sns.load_dataset('anscombe')

# %%
df.groupby('dataset').describe()

# %%
df.groupby('dataset').describe().T #Transposta

# %%
# Apresenta o resultado de uma regressão linear para cada dataset
sns.lmplot(x = 'x', y = 'y', col='dataset', 
          hue='dataset', data = df,
          col_wrap=2, ci=None, palette='muted', height=4,
          scatter_kws={'s':120, 'alpha':0.3})

plt.show()

# %% [markdown]
# ## Seaborn e Pandas
#
# As duas libs tem recursos interessantes e complementares

# %%
import random 
import pandas as pd
df = pd.DataFrame()

df['x'] = random.sample(range(1, 100), 25)
df['y'] = random.sample(range(1, 100), 25)

df.describe()

# %%
df

# %%
df.head()

# %%
sns.scatterplot(x='x', y='y', data=df);
sns.despine()

# %%
df.y

# %%
df.x

# %%
sns.kdeplot(df.y)

# %%
sns.kdeplot(df.x)

# %%
plt.hist(df.x, alpha=.5, color='red' );

# %%
plt.hist(df.y, alpha=.5, color='blue' );

# %%
plt.hist(df.x, alpha=.9)
sns.rugplot(df.x);

# %%
sns.boxplot(x=df.x);

# %%
sns.boxplot(y=df.y);

# %% [markdown]
# Dica:
#
# > Faça um rascunho em papel do gráfico que deseja<br>
# > Elabore o gráfico e crie uma função para reutiliza-lo - def<br>
# > Simplificar o uso, reutilizar os gráficos<br>
# > Separar o codigo de dados e de visualização
#
# <img src="https://www.bryanshalloway.com/2021/05/10/macros-in-the-shell-integrating-that-spreadsheet-from-finance-into-a-local-data-pipeline/images/excel-meme-dr-evil.jpg">
#
# ### LAB - Lista 3
#
# Análise de dados visual exploratória
#
# 1. Criar uma conta no Kaggle
# 2. Escolher um dado interessante
# 3. Baixar o arquivo CSV
# 4. Importar no **Pandas**
# 5. Visualizar os dados utilizando **Seaborn** e/ou **Matplotlib** para entender as informações
# 6. Compartilhar os gráficos com a turma (o arquivo notebook) na proxima aula de LAB
#
# ### LAB - Extra
#
# Conhecer as possibilidades de visualização de dados
#
# 1. Verificar no site do **Seaborn** e do **Matplotlib** exemplos de gráficos interessantes para sua área de atuação
# 2. Criar um notebook novo, copiar e colar os exemplos
# 3. Compartilhar com os colegas na próxima aula de LAB os gráficos que são interessantes para sua área de atuação
#
# - https://seaborn.pydata.org/examples/index.html
# - https://matplotlib.org/stable/gallery/index.html
#
# ![image.png](attachment:bdee5f56-0911-4ba2-bee5-72bd33ba5912.png)
#
# ### Tutorial online
#
# A documentação das LIBs em Python geralente são muito boas. Expeimento os tutoriais do Matplotlib e do Seaborn (em inglês):
# - https://matplotlib.org/stable/users/explain/quick_start.html
# - https://seaborn.pydata.org/tutorial/introduction.html
#
# ### Atividade Extra
#
# Iniciando na pandemia, publicamos dicas rápidas de Ciências dos Dados.<br>
# Continuamos adicionando novas dicas com base em perguntas de alunos, novidades, etc...<br>
# Disponíveis em:<br>
#
# - https://github.com/danielscarvalho/Insper-DS-Dicas

# %% [markdown]
# ### Referências:
#
# - https://matplotlib.org/
# - https://seaborn.pydata.org/
# - https://pandas.pydata.org/docs/
# - https://www.kaggle.com/
# - https://scikit-learn.org
