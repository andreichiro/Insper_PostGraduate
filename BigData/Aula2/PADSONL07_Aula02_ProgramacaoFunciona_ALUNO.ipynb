# %% [markdown]
# INSPER - Big Data
#
# # Big Data - Revisão - Programação Funcional
#
#
# ## Base de dados
#
# Vamos usar a base de "Saldo do cartão de crédito" para criar alguns processamentos solicitados na base original, filtrando valores, descobrindo outros e também criando novas colunas.
#
# **Importante**:
# 1. Vamos utilizar apenas a programação funcional para executar os comandos
# 2. Após exercícios de criação/alteração de dados, vamos exibir o resultado resumido com `df.head(5)`
# 3. Se necessário, vamos tratar erros de manipulação dos dados também com programação funcional
#
#
# Caso queira ver o significado dos dados, o dicionário está disponível no link : https://www.kaggle.com/avikpaul4u/credit-card-balance

# %% [markdown]
# Paradigmas de programação em Python:
# - Programação estruturada
# - Programação orientada a objetos
# - **Programação funcional**

# %% [markdown]
# Programação funcional é um **paradigma de programação**. Um modo de se programar usando **funções puras**, **evitando estados compartilhados**, **mutabilidade** e **efeitos adversos**
#
# Em vez da clássica programação imperativa, é uma programação **declarativa**
#
# Podemos dizer que programação funcional é um paradigma de programação que trata a computação como uma avaliação de funções matemáticas e que evita estados ou dados mutáveis
#
# Programação funcional é feita por meio do uso de **funções de ordem superior**, isto é, funções que recebem outras funções como argumentos e devolvem funções como resultado
#
# Características da programação funcional
#
# - Menos código
# - Maior abstração
# - Recursão, como oposição aos loops
# - Processamento de iteráveis
# - Códigos mágicos, pouco legíveis

# %% [markdown]
# **Funções puras** são funções que dadas as entradas, elas **SEMPRE** retornarão o **mesmo** resultado.
#
# Em linguagens puramente funcionais, os tipos de dados são naturalmente **imutáveis**. Isto facilita o ***paralelismo***.

# %% [markdown]
# **Desconstruindo a sintaxe da List Comprehension** ❗
#
#
# ```
# [x**2                 # ← transformação (mapeamento)
#  for x in numeros     # ← iteração
#  if x % 2 == 0]       # ← filtragem
# ```

# %%
# Import necessário e leitura da base. Adapte o que precisar
import pandas as pd
df = pd.read_csv("Credit.csv", sep=",")
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-62aec14b765b> in <cell line: 0>()
#       1 # Import necessário e leitura da base. Adapte o que precisar
#       2 import pandas as pd
# ----> 3 df = pd.read_csv("Credit.csv", sep=",")
#       4 df.head(5)
#
# ...

# %% [markdown]
# **A**. Considerando que a soma do saldo do crédito dos usuários é 208006, obtenha o mesmo valor a partir de manipulação da coluna `Balance`. Use o comando `reduce()`

# %%
df['Balance'].sum()
# Out:
# np.int64(208006)

# %%
from functools import reduce

# %%
reduce(lambda x, y: x+y, df['Balance'])
# Out:
# 208006

# %% [markdown]
# **B**. Crie uma coluna chamada `Gender 2` que converte Male -> M e Female -> F. Use os comandos `apply()` e `lambda`

# %%
df['Gender 2'] = df['Gender'].apply(lambda x: "M" if x == ' Male' else "F" if x == 'Female' else x)
df.head(5)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance Gender 2
# 0     Yes  Caucasian      333        M
# 1     Yes      Asian      903        F
# 2      No      Asian      580        M
# 3      No      Asian      964        F
# 4     Yes  Caucasian      331        M

# %% [markdown]
# **C**. Converta a coluna `Student` para binário, ou seja: Yes -> 1 ; No -> 0. Use os comandos `apply()` e `lambda`

# %% [markdown]
# **D**. Defina uma função `score()`, cujo retorno é o seguinte cálculo: "((cards+age)^student) / education". Agora crie uma nova coluna chamada `Score` que recebe o valor calculado. Use a função `map()`

# %% [markdown]
# **E**. Converta renda (Income) para `float`. Utileze uma função lambda armazenada numa variável chamada `convert_income`. Use também a função `map()`

# %% [markdown]
# **F**. Existe algum usuário com renda > 300k? Use a função `any()`

# %% [markdown]
# **G**. Quem são as pessoas com mais de 5 cartões de crédito? Use a função `filter()`
