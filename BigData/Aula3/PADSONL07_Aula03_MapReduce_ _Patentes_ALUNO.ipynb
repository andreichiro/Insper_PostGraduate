# %% [markdown]
# # Aula 03 - Introdução ao PySpark
#
# # Contagem de Patentes citadas (Map / Reduce Clássico)

# %%
# !wget https://raw.githubusercontent.com/daoleen/HadoopLearning/master/cite75_99.txt
# Out:
# zsh:1: command not found: wget

# %% [markdown]
# Ler o arquivo

# %% [markdown]
# ## MAP
#
# '3858241,956203' --> (956203, 1)

# %% [markdown]
# ## SHUFFLE

# %% [markdown]
# ## REDUCE

# %% [markdown]
# ## NO DASK

# %% [markdown]
# # Configurando Spark localmente
#
# Instalando o Spark na versão 3.5.1 no Colab. Eventualmente você precisará reiniciar seu ambiente.
#
# Note que esta já é a versão do Spark atualmente disponível no Colab, então o comando abaixo é desnecessário neste ambiente.
#
# Para instalar outras versões, basta mudar o número dela. Mas notem que podem haver conflitos entre bibliotecas. Em aula eu tentei instalar a versão 3.1.3 e não rolou. =)

# %%
# !pip install pyspark==3.5.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 43.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'pyspark' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pyspark'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...

# %% [markdown]
# # SETUP

# %% [markdown]
# Criar uma sessão do Spark

# %%
from pyspark.sql import SparkSession

# %%
spark

# %% [markdown]
# Crie um contexto (onde executamos comandos para os RDDs)
#
# * [SparkContext](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.SparkContext.html)

# %% [markdown]
# # Passo 1: Ler o arquivo em um RDD

# %% [markdown]
# * [textFile](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.SparkContext.textFile.html)

# %% [markdown]
# ## Uma primeira ação (take) ....

# %% [markdown]
# ## Precisamos remover o cabeçalho

# %% [markdown]
# ## Uma transformação: filter

# %% [markdown]
# ## Agora é o MAP --> '3858241, 956203' => (956203, 1)

# %% [markdown]
# ## Agora é o Reduce, obtendo então a quantidade de citações de cada patente
#
# * [reduceByKey](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.RDD.reduceByKey.html)

# %% [markdown]
# ## Agora é executar e obter o resultado

# %% [markdown]
# ## Obtendo as top-10 mais citadas ...uma nova ação: takeOrdered
#
# * [takeOrdered](https://spark.apache.org/docs/latest/api/python/reference/api/pyspark.RDD.takeOrdered.html)
